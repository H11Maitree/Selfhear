# %%
import pandas as pd
import numpy as np
import math

# %%
! ls
# Out:
# EQresult11-12-2019-10-00.csv Untitled.ipynb

# %%
df=pd.read_csv("EQresult11-12-2019-10-00.csv")

# %%
df
# Out:
#      Unnamed: 0 Say         g1         g2         g3         g4         g5  \
# 0             0  OO -16.161173 -14.549450 -14.666667 -16.717949 -17.216118
# 1             1  AR  -8.952381 -13.435898 -11.648350 -12.029305 -20.380953
# 2             2  AR  -7.721611  -5.347985  -6.578754 -12.175822  -6.813185
# 3             3  EE -19.531136  -8.630036  -6.783883 -13.465201 -17.245420
# 4             4  AR -14.959707  -6.842491  -7.545787  -9.098899 -11.531135
# 5             5  AR -14.725274 -13.142857 -11.941392 -14.608059 -21.347986
# 6             6  OO   0.000000 -19.706959 -21.875458 -23.516483 -23.428570
# 7             7  AR -11.853479   1.000000   1.000000   1.000000  -9.362636
# 8             8  EU -12.410255 -13.934065 -14.813186 -16.161173 -20.967031
# 9             9  OO -15.809524 -12.615383 -14.490843  -5.465201 -15.194139
# 10           10  AR -17.333334  -7.194139  -8.395602 -11.999998  -6.227106
# ...

# %%
import numpy as np

# %%
dfs=pd.DataFrame(columns=['Name','220','440','880','1760','2520'])
#queue=queue.append({'x':0,'y':0,'z':0,'distancepow2':0,'distance':0}, ignore_index=True)

# %%
print(np.mean(df['g1']))
print(np.mean(df['g2']))
print(np.mean(df['g3']))
print(np.mean(df['g4']))
print(np.mean(df['g5']))
dfs=dfs.append({'Name':"Mean","220":np.mean(df['g1']),"440":np.mean(df['g2']),"880":np.mean(df['g3']),"1760":np.mean(df['g4']),"2520":np.mean(df['g5'])}, ignore_index=True)
# Out:
# -10.60817089275672
# -9.975668719754768
# -9.802493039002785
# -10.233008739810723
# -11.860988467358625

# %%
print(np.mean(df[df['Say']=='AR']['g1']))
print(np.mean(df[df['Say']=='AR']['g2']))
print(np.mean(df[df['Say']=='AR']['g3']))
print(np.mean(df[df['Say']=='AR']['g4']))
print(np.mean(df[df['Say']=='AR']['g5']))
dfs=dfs.append({'Name':"AR","220":np.mean(df[df['Say']=='AR']['g1']),"440":np.mean(df[df['Say']=='AR']['g2']),"880":np.mean(df[df['Say']=='AR']['g3']),"1760":np.mean(df[df['Say']=='AR']['g4']),"2520":np.mean(df[df['Say']=='AR']['g5'])}, ignore_index=True)
# Out:
# -9.496636438640682
# -8.487378905578094
# -8.286179973862389
# -8.811121694608168
# -10.15924024365165

# %%
print(np.mean(df[df['Say']=='EE']['g1']))
print(np.mean(df[df['Say']=='EE']['g2']))
print(np.mean(df[df['Say']=='EE']['g3']))
print(np.mean(df[df['Say']=='EE']['g4']))
print(np.mean(df[df['Say']=='EE']['g5']))
dfs=dfs.append({'Name':"EE","220":np.mean(df[df['Say']=='EE']['g1']),"440":np.mean(df[df['Say']=='EE']['g2']),"880":np.mean(df[df['Say']=='EE']['g3']),"1760":np.mean(df[df['Say']=='EE']['g4']),"2520":np.mean(df[df['Say']=='EE']['g5'])}, ignore_index=True)
# Out:
# -10.669413477468948
# -10.1301065368148
# -10.026344899947826
# -10.484290755712069
# -12.075513647152828

# %%
print(np.mean(df[df['Say']=='EU']['g1']))
print(np.mean(df[df['Say']=='EU']['g2']))
print(np.mean(df[df['Say']=='EU']['g3']))
print(np.mean(df[df['Say']=='EU']['g4']))
print(np.mean(df[df['Say']=='EU']['g5']))
dfs=dfs.append({'Name':"EU","220":np.mean(df[df['Say']=='EU']['g1']),"440":np.mean(df[df['Say']=='EU']['g2']),"880":np.mean(df[df['Say']=='EU']['g3']),"1760":np.mean(df[df['Say']=='EU']['g4']),"2520":np.mean(df[df['Say']=='EU']['g5'])}, ignore_index=True)
# Out:
# -10.726926090670567
# -10.20182380080223
# -9.952021154702878
# -10.557135105133057
# -12.021259182224087

# %%
print(np.mean(df[df['Say']=='AA']['g1']))
print(np.mean(df[df['Say']=='AA']['g2']))
print(np.mean(df[df['Say']=='AA']['g3']))
print(np.mean(df[df['Say']=='AA']['g4']))
print(np.mean(df[df['Say']=='AA']['g5']))
dfs=dfs.append({'Name':"AA","220":np.mean(df[df['Say']=='AA']['g1']),"440":np.mean(df[df['Say']=='AA']['g2']),"880":np.mean(df[df['Say']=='AA']['g3']),"1760":np.mean(df[df['Say']=='AA']['g4']),"2520":np.mean(df[df['Say']=='AA']['g5'])}, ignore_index=True)
# Out:
# -11.167348532115712
# -10.427637217675938
# -10.362852159668417
# -10.90878351061952
# -12.653881489646201

# %%
print(np.mean(df[df['Say']=='OO']['g1']))
print(np.mean(df[df['Say']=='OO']['g2']))
print(np.mean(df[df['Say']=='OO']['g3']))
print(np.mean(df[df['Say']=='OO']['g4']))
print(np.mean(df[df['Say']=='OO']['g5']))
dfs=dfs.append({'Name':"OO","220":np.mean(df[df['Say']=='OO']['g1']),"440":np.mean(df[df['Say']=='OO']['g2']),"880":np.mean(df[df['Say']=='OO']['g3']),"1760":np.mean(df[df['Say']=='OO']['g4']),"2520":np.mean(df[df['Say']=='OO']['g5'])}, ignore_index=True)
# Out:
# -11.066508262765174
# -10.745097558288013
# -10.499604269569994
# -10.510306087194705
# -12.524311846962162

# %%
dfs.to_csv("Surway11_12_2019.csv")

# %%
dfs
# Out:
#    Name        220        440        880       1760       2520
# 0  Mean -10.608171  -9.975669  -9.802493 -10.233009 -11.860988
# 1    AR  -9.496636  -8.487379  -8.286180  -8.811122 -10.159240
# 2    EE -10.669413 -10.130107 -10.026345 -10.484291 -12.075514
# 3    EU -10.726926 -10.201824  -9.952021 -10.557135 -12.021259
# 4    AA -11.167349 -10.427637 -10.362852 -10.908784 -12.653881
# 5    OO -11.066508 -10.745098 -10.499604 -10.510306 -12.524312
