# %%
from FastModule import *

# %%
raw_sound=Spectrum.read_wav_file("Test_Lab/Sound_Files/BirthOrderandSuccess.wav")

# %%
Spectrum.plot_spectrum(raw_sound)

# %%
data=Spectrum.make_amplitude_per_frequency_DataFrame(raw_sound)
data=data[100:2500]

# %%
Spectrum.make_amplitude_per_frequency_DataFrame(raw_sound)
# Out:
#                  Amplitude  Normalized
# Frequency
# 0.000000      59563.209850    1.000000
# 0.002939         23.749364    0.000399
# 0.005877        109.742835    0.001842
# 0.008816         84.530238    0.001419
# 0.011754        117.123624    0.001966
# 0.014693         96.800042    0.001625
# 0.017631        142.141240    0.002386
# 0.020570        144.550478    0.002427
# 0.023508        126.321067    0.002121
# 0.026447        100.443992    0.001686
# 0.029385        114.832817    0.001928
# 0.032324         87.791973    0.001474
# 0.035262         75.998252    0.001276
# 0.038201         30.266796    0.000508
# 0.041139         45.618549    0.000766
# 0.044078         72.709436    0.001221
# 0.047016         93.873287    0.001576
# 0.049955        100.259803    0.001683
# 0.052893         57.328902    0.000962
# 0.055832        101.187601    0.001699
# 0.058770         97.900572    0.001643
# 0.061709        117.642018    0.001975
# 0.064647         81.043418    0.001360
# ...

# %%
data
# Out:
#                Amplitude  Normalized
# Frequency
# 100.000400   1382.344737    0.023208
# 100.003338   1191.216007    0.019999
# 100.006277    477.993842    0.008025
# 100.009215   3503.992305    0.058828
# 100.012154   1170.152998    0.019645
# 100.015092    541.543340    0.009092
# 100.018031    782.483747    0.013137
# 100.020969   1376.633892    0.023112
# 100.023908   1557.796390    0.026153
# 100.026846    350.900513    0.005891
# 100.029785   2131.892071    0.035792
# 100.032723   2537.769379    0.042606
# 100.035662    684.277102    0.011488
# 100.038600   1085.892508    0.018231
# 100.041539   1102.440496    0.018509
# 100.044477   2662.975557    0.044708
# 100.047416    613.771633    0.010304
# 100.050354   1662.986272    0.027920
# 100.053293   1600.898465    0.026877
# 100.056231   1740.605261    0.029223
# 100.059170    750.451419    0.012599
# 100.062108    491.052798    0.008244
# 100.065047   1405.125492    0.023590
# 100.067986    691.331237    0.011607
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
#ax = plt.gca()
data.plot(kind='line',y='Amplitude')

plt.show()
