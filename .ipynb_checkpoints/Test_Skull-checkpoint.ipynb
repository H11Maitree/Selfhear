# %%
from FastModule import *

# %%
raw_sound=Spectrum.read_wav_file("Test_Lab/Sound_Files/before-skull.wav")

# %%
Spectrum.plot_spectrum(raw_sound)

# %%
data1=Spectrum.make_amplitude_per_frequency_DataFrame(raw_sound)

# %%
raw_sound=Spectrum.read_wav_file("Test_Lab/Sound_Files/inside-skull.wav")
Spectrum.plot_spectrum(raw_sound)

# %%
data2=Spectrum.make_amplitude_per_frequency_DataFrame(raw_sound)

# %%
#data2[(data2.Frequency>500) & (data2.Frequency<600)]

# %%
import numpy as np
mask1=data1
mask2=data2

# %%
mask1=mask1[mask1.index<2500]
mask2=mask2[mask2.index<2500]

# %%
import matplotlib.pyplot as plt
import pandas as pd
#ax = plt.gca()
mask1.plot(kind='line',y='Amplitude')
mask2.plot(kind='line',y='Amplitude', color='red')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
ax = plt.gca()

mask2.plot(kind='line',y='Amplitude', color='red',ax=ax)
mask1.plot(kind='line',y='Amplitude',ax=ax)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
ax = plt.gca()
mask2.plot(kind='line',y='Normalized', color='red',ax=ax)
mask1.plot(kind='line',y='Normalized',ax=ax)
plt.show()

# %%
Comparison.caculate_trasmission(data1,data2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-80b5f7e67edf> in <module>
# ----> 1 Comparison.caculate_trasmission(data1,data2)
#
# ~\Documents\GitHub\Selfhear\FastModule\Comparison.py in caculate_trasmission(datain, dataout, colum)
#       9     dataf=pd.DataFrame()
#      10     dataf['Frequency']=datain.index
# ---> 11     dataf['Percent_out_per_in']=np.array(dataout[colum])/np.array(datain[colum])
#      12     dataf['Normalized_Percent']=scaler.fit_transform((np.array(dataf.Percent_out_per_in)).reshape(-1,1))
#      13     dataf['Normalized_Percent_loss']=1-dataf['Normalized_Percent']
#
# ValueError: operands could not be broadcast together with shapes (812737,) (801793,)
